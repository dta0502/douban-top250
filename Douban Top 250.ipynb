# %% [markdown]
# # 豆瓣电影TOP250抓取
# 本文是Python爬取豆瓣的top250电影的分析和实现，具体是将电影的标题、电影描述、电影的评分、电影的评论数以及电影的一句影评抓取下来，然后输出csv文件。
#
# - 第一步：打开豆瓣电影top250这个页面。
# - 第二步：分析网页源代码，找到我们需要爬取的信息的标签，例如电影title的标签等等是什么。
# - 第三步：写代码了，将整个html请求下来，然后解析网页，获取我们需要的信息，利用lxml进行解析。

# %% [markdown]
# ## 网页分析
# 首先打开豆瓣电影top250，我们可以看到电影是按照一个列表呈现出来的，页面是通过最底部的12345...来进行翻页查看的。
#
# ### 定位页面元素
# 我通过chrome的开发者工具来分析页面元素。下面是chrome的检查的页面：
# ![chrome页面元素选择](./images/chrome页面元素选择.png)
#
# 点击上图中画圆圈的图标，然后自己鼠标在页面上选中一部分，就会直接定位到具体的地方了。
#
# ### 电影信息的位置
# 通过上面所说的方法，我们可以观察得到所有列表是放在一个`class = 'grid_view'`的ol标签中的，这个标签下的每一个li标签就是每一部电影信息的Item。
# #### ol标签的XPath路径
# ```XML
# //*[@id="content"]/div/div[1]/ol
# ```
# #### 电影标题的XPath路径
# ```XML
# //*[@id="content"]/div/div[1]/ol/li[1]/div/div[2]/div[1]/a/span[1]
# ```
# #### 电影的描述
# ```XML
# //*[@id="content"]/div/div[1]/ol/li[1]/div/div[2]/div[2]/p[1]
# ```
# #### 电影评分的XPath路径
# ```XML
# //*[@id="content"]/div/div[1]/ol/li[1]/div/div[2]/div[2]/div/span[2]
# ```
# #### 电影评论数的XPath路径
# ```XML
# //*[@id="content"]/div/div[1]/ol/li[1]/div/div[2]/div[2]/div/span[4]
# ```
# #### 电影的一句经典影评
# ```XML
# //*[@id="content"]/div/div[1]/ol/li[1]/div/div[2]/div[2]/p[2]/span
# ```
#
# ### 翻页
# 每一页网址的变化规律，一页可以显示25部电影，就是说这250部电影一共有10页。观察前几页的网址很容易发现规律：就是start后面跟的参数变化，等于（页数-1）\*25，而且发现后面的filter去掉也不影响。
# ```
# https://movie.douban.com/top250?start=0
# https://movie.douban.com/top250?start=25
# ...
# https://movie.douban.com/top250?start=225
# ```

# %% [markdown]
# ** 现在完成了整个网页的分析，下面开始实现爬取。 **

# %% [markdown]
# ## Python实现爬取(baseline model)
# ### 导入第三方库
#
# #### [requests](http://docs.python-requests.org/en/latest/#)
# requests模块取代内建的urllib2模块，因为其速度更快而且可读性更好。
#
# #### [lxml](http://lxml.de/)
# lxml是一个优美的扩展库，用来快速解析XML以及HTML文档即使所处理的标签非常混乱。

# %%
import requests
from lxml import etree
import csv

# %% [markdown]
# ### requests获取页面
# 这里我们将使用 requests.get 来从页面中取得我们的数据， 通过使用 html 模块解析它，并将结果保存到 tree 中。

# %%
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36'}
data = requests.get(url,headers = headers).text

# %%
selector = etree.HTML(data)

# %% [markdown]
# etree现在包含了整个HTML文件到一个优雅的树结构中，我们可以使用两种方法访问：
# - XPath：XPath是一种在结构化文档（如HTML或XML）中定位信息的方式。
# - CSS选择器。
#
# 下面我采用XPath方法来定位信息。

# %% [markdown]
# ### 得到想要的信息的XPath路径
# Chrome可以右键元素，选择‘Inspect element'，高亮这段代码，再次右击，并选择‘Copy XPath'。

# %%
film=selector.xpath('//*[@id="content"]/div/div[1]/ol/li')

# %%
film
# Out:
# [<Element li at 0x2d219e26b48>,
#  <Element li at 0x2d219e26a48>,
#  <Element li at 0x2d219e3c308>,
#  <Element li at 0x2d219e3cd08>,
#  <Element li at 0x2d219e3cf48>,
#  <Element li at 0x2d219e59288>,
#  <Element li at 0x2d219e59348>,
#  <Element li at 0x2d219e59388>,
#  <Element li at 0x2d219e593c8>,
#  <Element li at 0x2d219e592c8>,
#  <Element li at 0x2d219e59308>,
#  <Element li at 0x2d219e59488>,
#  <Element li at 0x2d219e59408>,
#  <Element li at 0x2d219e594c8>,
#  <Element li at 0x2d219e59508>,
#  <Element li at 0x2d219e59548>,
#  <Element li at 0x2d219e59588>,
#  <Element li at 0x2d219e595c8>,
#  <Element li at 0x2d219e59648>,
#  <Element li at 0x2d219e59188>,
#  <Element li at 0x2d219e59048>,
#  <Element li at 0x2d219e59208>,
#  <Element li at 0x2d219e59808>,
#  <Element li at 0x2d219e597c8>,
#  <Element li at 0x2d219e59788>]

# %%
for div in film:
    title = div.xpath('div/div[2]/div[1]/a/span[1]/text()')[0]
    describe = div.xpath('div/div[2]/div[2]/p[1]/text()') #这里我爬取了年份、国家、类型这三个参数，忽略了导演等参数
    rating = div.xpath('div/div[2]/div[2]/div/span[2]/text()')[0]
    comments_nums = div.xpath('div/div[2]/div[2]/div/span[4]/text()')[0]
    comments = div.xpath('div/div[2]/div[2]/p[2]/span/text()')[0]

# %% [markdown]
# 下面看下得到的信息：

# %%
title
# Out:
# '怦然心动'

# %%
describe[0]
# Out:
# '\n                            导演: 罗伯·莱纳 Rob Reiner\xa0\xa0\xa0主演: 玛德琳·卡罗尔 Madeline Carroll / 卡...'

# %%
describe[0].lstrip()
# Out:
# '导演: 罗伯·莱纳 Rob Reiner\xa0\xa0\xa0主演: 玛德琳·卡罗尔 Madeline Carroll / 卡...'

# %%
describe[0].lstrip().split('\xa0\xa0\xa0')
# Out:
# ['导演: 罗伯·莱纳 Rob Reiner', '主演: 玛德琳·卡罗尔 Madeline Carroll / 卡...']

# %%
describe[1]
# Out:
# '\n                            2010\xa0/\xa0美国\xa0/\xa0剧情 喜剧 爱情\n                        '

# %%
describe[1].lstrip() #lstrip = left strip =去除（字符串）左边的
# Out:
# '2010\xa0/\xa0美国\xa0/\xa0剧情 喜剧 爱情\n                        '

# %%
describe[1].lstrip().rstrip() #rstrip = right strip =去除（字符串）右边的
# Out:
# '2010\xa0/\xa0美国\xa0/\xa0剧情 喜剧 爱情'

# %%
describe[1].lstrip().rstrip().split('\xa0/\xa0')
# Out:
# ['2010', '美国', '剧情 喜剧 爱情']

# %%
rating
# Out:
# '8.9'

# %%
comments_nums
# Out:
# '691156人评价'

# %%
comments_nums[:-3]
# Out:
# '691156'

# %%
comments
# Out:
# '真正的幸福是来自内心深处。'

# %% [markdown]
# ## 完整实现

# %%
import requests
from lxml import etree
import csv

# %%
top250_url = 'https://movie.douban.com/top250?start={}&filter='
movie_name = '名称'
movie_year = '年份'
movie_country = '国家'
movie_type = '类型'
movie_director = '导演'
movie_assess = '评价人数'
movie_score = '评分'
movie_num = 0

# %%
with open('top250_movie.csv','w',newline = '',encoding = 'utf-8') as f:
    writer = csv.writer(f)
    writer.writerow([movie_num,movie_name,movie_year,movie_country,movie_type,movie_director,movie_assess,movie_score])
    for lists in range(10):
        movie_content = requests.get(top250_url.format(lists*25)).text
        selector = etree.HTML(movie_content)
        all_list = selector.xpath('//*[@id="content"]/div/div[1]/ol/li')
        for item in all_list:
            movie_name = item.xpath('div/div[2]/div[1]/a/span[1]/text()')[0]
            movie_assess = item.xpath('div/div[2]/div[2]/div/span[4]/text()')[0][:-3]
            movie_score = item.xpath('div/div[2]/div[2]/div/span[2]/text()')[0]
            movie_num += 1
            # 下面将电影的介绍信息进行整理
            movie_intro = item.xpath('div/div[2]/div[2]/p[1]/text()')
            movie_actor_infos = movie_intro[0].lstrip().split('\xa0\xa0\xa0')
            movie_other_infos = movie_intro[1].lstrip().rstrip().split('\xa0/\xa0')
            # 下面是导演信息
            movie_director = movie_actor_infos[0][3:]
            # 下面是电影上映的年份
            movie_year = movie_other_infos[0]
            # 下面是电影的国家
            movie_country = movie_other_infos[1]
            # 下面是电影的类型
            movie_type = movie_other_infos[2]
            
            writer.writerow([movie_num,movie_name,movie_year,movie_country,movie_type,movie_director,movie_assess,movie_score])

# %% [markdown]
# ## 结果

# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("top250_movie.csv",encoding = 'utf-8')
df
# Out:
#        0         名称    年份                国家              类型  \
# 0      1     肖申克的救赎  1994                美国           犯罪 剧情
# 1      2       霸王别姬  1993           中国大陆 香港        剧情 爱情 同性
# 2      3    这个杀手不太冷  1994                法国        剧情 动作 犯罪
# 3      4       阿甘正传  1994                美国           剧情 爱情
# 4      5       美丽人生  1997               意大利     剧情 喜剧 爱情 战争
# 5      6      泰坦尼克号  1997                美国        剧情 爱情 灾难
# 6      7       千与千寻  2001                日本        剧情 动画 奇幻
# 7      8     辛德勒的名单  1993                美国        剧情 历史 战争
# 8      9       盗梦空间  2010             美国 英国     剧情 科幻 悬疑 冒险
# 9     10     机器人总动员  2008                美国     爱情 科幻 动画 冒险
# 10    11    忠犬八公的故事  2009             美国 英国              剧情
# 11    12    三傻大闹宝莱坞  2009                印度     剧情 喜剧 爱情 歌舞
# 12    13      海上钢琴师  1998               意大利           剧情 音乐
# 13    14     放牛班的春天  2004          法国 瑞士 德国           剧情 音乐
# 14    15  大话西游之大圣娶亲  1995           香港 中国大陆     喜剧 爱情 奇幻 冒险
# 15    16      楚门的世界  1998                美国           剧情 科幻
# 16    17         教父  1972                美国           剧情 犯罪
# 17    18         龙猫  1988                日本        动画 奇幻 冒险
# 18    19       星际穿越  2014      美国 英国 加拿大 冰岛        剧情 科幻 冒险
# 19    20         熔炉  2011                韩国              剧情
# 20    21        无间道  2002                香港        剧情 犯罪 悬疑
# 21    22       触不可及  2011                法国           剧情 喜剧
# 22    23       乱世佳人  1939                美国     剧情 历史 爱情 战争
# 23    24     当幸福来敲门  2006                美国        剧情 传记 家庭
# 24    25       怦然心动  2010                美国        剧情 喜剧 爱情
# 25    26      天堂电影院  1988            意大利 法国           剧情 爱情
# 26    27      疯狂动物城  2016                美国        喜剧 动画 冒险
# 27    28       十二怒汉  1957                美国              剧情
# 28    29   蝙蝠侠：黑暗骑士  2008             美国 英国  剧情 动作 科幻 犯罪 惊悚
# 29    30       鬼子来了  2000              中国大陆        剧情 历史 战争
# ..   ...        ...   ...               ...             ...
# 220  221    爱在午夜降临前  2013                美国           剧情 爱情
# 221  222   E.T. 外星人  1982                美国           剧情 科幻
# 222  223      无敌破坏王  2012                美国     喜剧 动画 奇幻 冒险
# 223  224        发条橙  1971             英国 美国        犯罪 剧情 科幻
# 224  225      疯狂的石头  2006           中国大陆 香港           喜剧 犯罪
# 225  226      黄金三镖客  1966        意大利 西班牙 西德           冒险 西部
# 226  227       海街日记  2015                日本           剧情 家庭
# 227  228       美国丽人  1999                美国        剧情 爱情 家庭
# 228  229       荒野生存  2007                美国        冒险 传记 剧情
# 229  230       迁徙的鸟  2001  法国 德国 意大利 西班牙 瑞士             纪录片
# 230  231       英国病人  1996             美国 英国        爱情 剧情 战争
# 231  232    彗星来的那一夜  2013             美国 英国        科幻 悬疑 惊悚
# 232  233      国王的演讲  2010        英国 澳大利亚 美国        剧情 传记 历史
# 233  234         血钻  2006             美国 德国        剧情 惊悚 冒险
# 234  235      非常嫌疑犯  1995             德国 美国     剧情 犯罪 悬疑 惊悚
# 235  236         聚焦  2015                美国           剧情 传记
# 236  237        燕尾蝶  1996                日本           犯罪 剧情
# 237  238         勇士  2011                美国        剧情 运动 家庭
# 238  239      叫我第一名  2008                美国           剧情 传记
# 239  240       穆赫兰道  2001             法国 美国        剧情 悬疑 惊悚
# 240  241       遗愿清单  2007                美国        冒险 喜剧 剧情
# 241  242         枪火  1999                香港        剧情 动作 犯罪
# 242  243        我爱你  2011                韩国           剧情 爱情
# 243  244       黑鹰坠落  2001                美国        动作 历史 战争
# 244  245      上帝也疯狂  1980           博茨瓦纳 南非              喜剧
# 245  246       荒岛余生  2000                美国           冒险 剧情
# 246  247   大卫·戈尔的一生  2003          美国 德国 英国        剧情 犯罪 悬疑
# 247  248       千钧一发  1997                美国        剧情 科幻 惊悚
# 248  249   2001太空漫游  1968             英国 美国        科幻 惊悚 冒险
# 249  250       蓝色大门  2002             台湾 法国        剧情 爱情 同性
#
#                                                    导演     评价人数   评分
# 0                             弗兰克·德拉邦特 Frank Darabont  1111833  9.6
# 1                                      陈凯歌 Kaige Chen   811410  9.5
# 2                                    吕克·贝松 Luc Besson  1030489  9.4
# 3                                     Robert Zemeckis   878944  9.4
# 4                             罗伯托·贝尼尼 Roberto Benigni   513037  9.5
# 5                               詹姆斯·卡梅隆 James Cameron   817615  9.3
# 6                                  宫崎骏 Hayao Miyazaki   818349  9.3
# 7                          史蒂文·斯皮尔伯格 Steven Spielberg   464382  9.4
# 8                          克里斯托弗·诺兰 Christopher Nolan   906557  9.3
# 9                              安德鲁·斯坦顿 Andrew Stanton   597466  9.3
# 10                           莱塞·霍尔斯道姆 Lasse Hallström   574928  9.3
# 11                            拉库马·希拉尼 Rajkumar Hirani   815020  9.2
# 12                        朱塞佩·托纳多雷 Giuseppe Tornatore   688692  9.2
# 13                     克里斯托夫·巴拉蒂 Christophe Barratier   552100  9.2
# 14                                    刘镇伟 Jeffrey Lau   606392  9.2
# 15                                   彼得·威尔 Peter Weir   581448  9.1
# 16                   弗朗西斯·福特·科波拉 Francis Ford Coppola   410480  9.2
# 17                                 宫崎骏 Hayao Miyazaki   505223  9.1
# 18                         克里斯托弗·诺兰 Christopher Nolan   604179  9.2
# 19                                黄东赫 Dong-hyuk Hwang   336043  9.2
# 20                                          刘伟强 / 麦兆辉   493185  9.1
# 21    奥利维·那卡什 Olivier Nakache / 艾力克·托兰达 Eric Toledano   441150  9.2
# 22        维克多·弗莱明 Victor Fleming / 乔治·库克 George Cukor   316000  9.2
# 23                          加布里尔·穆奇诺 Gabriele Muccino   650089  9.0
# 24                                   罗伯·莱纳 Rob Reiner   691156  8.9
# 25                        朱塞佩·托纳多雷 Giuseppe Tornatore   351670  9.1
# 26             拜伦·霍华德 Byron Howard / 瑞奇·摩尔 Rich Moore   646154  9.1
# 27                                       Sidney Lumet   202095  9.4
# 28                         克里斯托弗·诺兰 Christopher Nolan   398480  9.1
# 29                                       姜文 Wen Jiang   280901  9.2
# ..                                                ...      ...  ...
# 220                        理查德·林克莱特 Richard Linklater   128997  8.8
# 221                                  Steven Spielberg   167955  8.5
# 222                                  瑞奇·莫尔 Rich Moore   203820  8.6
# 223                                   Stanley Kubrick   200082  8.5
# 224                                       宁浩 Hao Ning   349938  8.3
# 225                                      Sergio Leone    56694  9.1
# 226                             是枝裕和 Hirokazu Koreeda   151243  8.7
# 227                                 萨姆·门德斯 Sam Mendes   199839  8.5
# 228                                    西恩·潘 Sean Penn   137131  8.6
# 229    雅克·贝汉 Jacques Perrin / 雅克·克鲁奥德 Jacques Cluzaud    54676  9.1
# 230                         安东尼·明格拉 Anthony Minghella   185002  8.5
# 231                      詹姆斯·沃德·布柯特 James Ward Byrkit   203368  8.4
# 232                                  汤姆·霍珀 Tom Hooper   367337  8.3
# 233                              爱德华·兹威克 Edward Zwick   146490  8.5
# 234                               布莱恩·辛格 Bryan Singer   126329  8.6
# 235                           托马斯·麦卡锡 Thomas McCarthy   140653  8.8
# 236                                  岩井俊二 Shunji Iwai   113088  8.6
# 237                             加文·欧康诺 Gavin O'Connor    93434  8.9
# 238                                彼得·维纳 Peter Werner   116623  8.6
# 239                                 大卫·林奇 David Lynch   252545  8.3
# 240                                  罗伯·莱纳 Rob Reiner   143374  8.5
# 241                                    杜琪峰 Johnnie To   108396  8.6
# 242                                秋昌民 Chang-min Choo    63998  9.0
# 243                              雷德利·斯科特 Ridley Scott   128137  8.6
# 244                                         Jamie Uys   102778  8.6
# 245                          罗伯特·泽米吉斯 Robert Zemeckis   147319  8.5
# 246                                       Alan Parker   103732  8.6
# 247                             安德鲁·尼科尔 Andrew Niccol    94953  8.7
# 248                          斯坦利·库布里克 Stanley Kubrick   103404  8.7
# 249                                  易智言 Chih-yen Yee   287039  8.3
#
# [250 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
# 0       250 non-null int64
# 名称      250 non-null object
# 年份      250 non-null object
# 国家      250 non-null object
# 类型      250 non-null object
# 导演      250 non-null object
# 评价人数    250 non-null int64
# 评分      250 non-null float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 15.7+ KB

# %% [markdown]
# ## 遇到的问题
# - csv文件产生空行的问题
# - Excel打开csv出现乱码怎么解决

# %% [markdown]
# ## 参考
# - [使用python抓取豆瓣top250电影数据进行分析](https://www.jianshu.com/p/720b193a5c2b)
# - [Python爬虫一：抓取豆瓣电影Top250](https://blog.csdn.net/xing851483876/article/details/80578998)
